# %% [markdown]
# <a href="https://colab.research.google.com/github/Crisitunity-Lab/ARDC-Project/blob/main/Llama2_prod_r5_final%20prompts_filtershort%20tweet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Llama2 Production
#
# SUMA 26/09/2023

# %% [markdown]
# #Instructions
#
# Running code on Google Colab
# 1.   Create HuggingFace account
# 2.   Gain access to model: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf
# 3.   Create folder 'data' in project folder on personal Google Drive
# 4.   Save data set CrisiLexT26 in folder 'data'
# 5.   Data sourced from: https://crisislex.org/data-collections.html#CrisisLexT26
# 6.   Mount Google Drive
# 7.   Update code with Paths
# 8.   Set system up as per steps below
# 9.   Run Experiments
# 10.  Evaluate

# %% [markdown]
# ## Setup

# %%
# Install Transformer package
# !pip install -q transformers einops accelerate langchain bitsandbytes

# %%
# Import Packages
from langchain import PromptTemplate,  LLMChain
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer
import transformers
import torch
import pandas as pd
import numpy as np
import json
import os
import csv
import time
import re
import matplotlib.pyplot as plt
import json

# %%
# Mounting GDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Prerequisites
#
# To load our desired model, `meta-llama/Llama-2-7b-chat-hf`, we first need to authenticate ourselves on Hugging Face. This ensures we have the correct permissions to fetch the model.
#
# 1. Gain access to the model on Hugging Face: [Link](https://huggingface.co/meta-llama/Llama-2-7b-chat-hf).
# 2. Use the Hugging Face CLI to login and verify your authentication status.

# %%
# Logging onto HuggingFace
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %% [markdown]
# ## Preparing data

# %%
# Read (timestamps)

# Path to the main folder
main_folder = '/content/gdrive/MyDrive/iLab2/data/CrisisLexT26'

# Function to process CSV files in a folder
def process_folder(folder_path):
    dfs = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.csv') and 'period' in file.lower():
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                dfs.append(df)
    return dfs

# Read and process each subfolder
combined_data = []
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)
    if os.path.isdir(subfolder_path):
        subfolder_data = process_folder(subfolder_path)
        combined_data.extend(subfolder_data)

# Concatenate all data into one DataFrame
combined_df_p = pd.concat(combined_data, ignore_index=True)


# Remove spaces from column names
combined_df_p.columns = combined_df_p.columns.str.replace(' ', '')

# Rename Columns in prep for left join
combined_df_p.rename(columns={'Tweet-ID': 'Tweet ID'}, inplace=True)

# # Save the combined DataFrame to a CSV file
# output_file = 'combined_data.csv'
# combined_df.to_csv(output_file, index=False)

print(f"Combined timestamps read")
# Out:
# Combined timestamps read

# %%
# Read tweets

# Path to the main folder
main_folder = '/content/gdrive/MyDrive/iLab2/data/CrisisLexT26'

# Function to process CSV files in a folder, add folder name as label, and add subfolder name as a column
def process_folder(folder_path, label, subfolder_name):
    dfs = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.csv') and 'labeled' in file.lower():
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                df['Label'] = label
                df['subfolder_name'] = subfolder_name  # Add subfolder name as a column
                dfs.append(df)
    return dfs

# Read and process each subfolder
combined_data = []
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)
    if os.path.isdir(subfolder_path):
        label = subfolder
        subfolder_data = process_folder(subfolder_path, label, subfolder)
        combined_data.extend(subfolder_data)

# Concatenate all data into one DataFrame
combined_df_l = pd.concat(combined_data, ignore_index=True)

# Print the first few rows of the combined DataFrame
print(f"Combined tweets read")
combined_df_l.head(10)
# Out:
# Combined tweets read
#              Tweet ID                                         Tweet Text  \
# 0  242883454050648064  #earthquake M 3.3, Virgin Islands region: Sept...
# 1  242887379944366080     @EarthquakeTest update your #earthquake s more
# 2  242919634125328384  RT @RedazioneWebAL: #Terremoto, Costi (Pd): ta...
# 3  242920737223106561  #Earthquake M 2.6, Southern Alaska http://t.co...
# 4  242936558158757889  ５年６ヶ月長期保存可能なえいようかん5本。http://t.co/ZlSVctfi #eqj...
# 5  242945299084103681      #earthquake sige najud ug linug diri ui.. =.=
# 6  242950005076393985  @MRmusica pasenla super bien :) Mil besos desd...
# 7  242951548576088065  RT @TerreInMoto: I Negozi di Mirandola 3 Mesi ...
# 8  242979541373562880  #earthquake Philippines (the): NDRRMC Update r...
# 9  242997841134505985  【#USGS #Breaking】 M 1.1, 28km SSW of Fairbanks...
#
#    Information Source  Information Type  Informativeness  \
# 0         Not labeled       Not labeled      Not related
# 1         Not labeled       Not labeled      Not related
# 2         Not labeled       Not labeled      Not related
# 3         Not labeled       Not labeled      Not related
# 4         Not labeled       Not labeled   Not applicable
# 5         Not labeled       Not labeled   Not applicable
# 6         Not labeled       Not labeled      Not related
# 7         Not labeled       Not labeled      Not related
# 8         Not labeled       Not labeled      Not related
# 9         Not labeled       Not labeled   Not applicable
#
#                         Label              subfolder_name
# 0  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 1  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 2  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 3  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 4  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 5  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 6  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 7  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 8  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 9  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake

# %%
# Check
combined_df_p.columns
combined_df_p.head()
# Out:
#                         Timestamp            Tweet ID Included(Y/N)
# 0  Sun Sep 16 06:07:51 +0000 2012  247215201198436352             Y
# 1  Sun Sep 16 06:08:01 +0000 2012  247215243137257472             Y
# 2  Sun Sep 16 06:10:16 +0000 2012  247215809372516353             Y
# 3  Sun Sep 16 06:39:34 +0000 2012  247223182979911681             Y
# 4  Sun Sep 16 06:41:20 +0000 2012  247223627584520192             Y

# %%
# Extract earliest timestamp

# Convert it to datetime first
combined_df_p['Timestamp'] = pd.to_datetime(combined_df_p['Timestamp'])

# Group by 'Tweet-ID' and aggregate to find the earliest timestamp
earliest_timestamps = combined_df_p.groupby('Tweet ID')['Timestamp'].agg('min').reset_index()

# Display or use the resulting DataFrame 'earliest_timestamps'
# print(earliest_timestamps)

# %%
# Left join

# Perform a left join on 'Tweet ID'
result_df = combined_df_l.merge(earliest_timestamps, on='Tweet ID', how='left')

# Display
# print(result_df)
# result_df.shape
result_df.head()
# Out:
#              Tweet ID                                         Tweet Text  \
# 0  242883454050648064  #earthquake M 3.3, Virgin Islands region: Sept...
# 1  242887379944366080     @EarthquakeTest update your #earthquake s more
# 2  242919634125328384  RT @RedazioneWebAL: #Terremoto, Costi (Pd): ta...
# 3  242920737223106561  #Earthquake M 2.6, Southern Alaska http://t.co...
# 4  242936558158757889  ５年６ヶ月長期保存可能なえいようかん5本。http://t.co/ZlSVctfi #eqj...
#
#    Information Source  Information Type  Informativeness  \
# 0         Not labeled       Not labeled      Not related
# 1         Not labeled       Not labeled      Not related
# 2         Not labeled       Not labeled      Not related
# 3         Not labeled       Not labeled      Not related
# 4         Not labeled       Not labeled   Not applicable
#
#                         Label              subfolder_name  \
# 0  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 1  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 2  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 3  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
# 4  2012_Costa_Rica_earthquake  2012_Costa_Rica_earthquake
#
#                   Timestamp
# 0 2012-09-04 07:15:02+00:00
# 1 2012-09-04 07:30:38+00:00
# 2 2012-09-04 09:38:48+00:00
# 3 2012-09-04 09:43:11+00:00
# 4 2012-09-04 10:46:03+00:00

# %%
# Read

# Define the main folder path
main_folder = '/content/gdrive/MyDrive/iLab2/data/CrisisLexT26'

# Initialize empty lists to store the extracted data
subfolder_names = []
names = []
start_days = []
durations = []
countries = []
location_descriptions = []
sub_categories = []
types = []

# Loop through the subfolders
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)

    # Check if it's a directory
    if os.path.isdir(subfolder_path):
        json_files = [f for f in os.listdir(subfolder_path) if f.endswith('.json')]

        # Loop through JSON files in the subfolder
        for json_file in json_files:
            json_path = os.path.join(subfolder_path, json_file)

            # Read the JSON file
            with open(json_path, 'r') as f:
                data = json.load(f)

                # Extract the required information
                subfolder_names.append(subfolder)
                names.append(data['name'])
                start_days.append(data['time']['start_day'])
                durations.append(data['time']['duration'])
                countries.append(data['location']['country'])
                location_descriptions.append(data['location']['location_description'])
                sub_categories.append(data['categorization']['sub_category'])
                types.append(data['categorization']['type'])

# Create a DataFrame from the extracted data
df_annotation = pd.DataFrame({
    'subfolder_name': subfolder_names,
    'name': names,
    'start_day': start_days,
    'duration': durations,
    'country': countries,
    'location_description': location_descriptions,
    'sub_category': sub_categories,
    'type': types
})

# Display the DataFrame
df_annotation.head()
# Out:
#                subfolder_name                          name   start_day  \
# 0  2012_Costa_Rica_earthquake         Costa Rica earthquake  2012-09-04
# 1     2012_Venezuela_refinery  Venezuela refinery explosion  2012-08-24
# 2         2013_Alberta_floods                Alberta Floods  17/06/2013
# 3     2013_Australia_bushfire           Australia wildfires  2013-10-12
# 4   2012_Guatemala_earthquake          Guatemala earthquake  2012-11-06
#
#    duration     country location_description    sub_category        type
# 0        13  Costa Rica           Costa Rica     Geophysical  Earthquake
# 1        12   Venezuela               Falcon   Unintentional   Explosion
# 2        25      Canada              Alberta    Hydrological      Floods
# 3        21   Australia      New South Wales  Climatological    Wildfire
# 4        20   Guatemala            Guatemala     Geophysical  Earthquake

# %%
# Left join

# Perform a left join on the 'subfolder'
result_df = result_df.merge(df_annotation, left_on='subfolder_name', right_on='subfolder_name', how='left')

# Drop the duplicate 'subfolder_name'
result_df.drop(columns=['subfolder_name'], inplace=True)

# %%
# Count the number of rows in result_df
row_count = result_df.shape[0]

# Print the row count
print(f"Number of rows in result_df: {row_count}")

result_df.head()
# Out:
# Number of rows in result_df: 27933
#              Tweet ID                                         Tweet Text  \
# 0  242883454050648064  #earthquake M 3.3, Virgin Islands region: Sept...
# 1  242887379944366080     @EarthquakeTest update your #earthquake s more
# 2  242919634125328384  RT @RedazioneWebAL: #Terremoto, Costi (Pd): ta...
# 3  242920737223106561  #Earthquake M 2.6, Southern Alaska http://t.co...
# 4  242936558158757889  ５年６ヶ月長期保存可能なえいようかん5本。http://t.co/ZlSVctfi #eqj...
#
#    Information Source  Information Type  Informativeness  \
# 0         Not labeled       Not labeled      Not related
# 1         Not labeled       Not labeled      Not related
# 2         Not labeled       Not labeled      Not related
# 3         Not labeled       Not labeled      Not related
# 4         Not labeled       Not labeled   Not applicable
#
#                         Label                 Timestamp  \
# 0  2012_Costa_Rica_earthquake 2012-09-04 07:15:02+00:00
# 1  2012_Costa_Rica_earthquake 2012-09-04 07:30:38+00:00
# 2  2012_Costa_Rica_earthquake 2012-09-04 09:38:48+00:00
# 3  2012_Costa_Rica_earthquake 2012-09-04 09:43:11+00:00
# 4  2012_Costa_Rica_earthquake 2012-09-04 10:46:03+00:00
#
#                     name   start_day  duration     country  \
# 0  Costa Rica earthquake  2012-09-04        13  Costa Rica
# 1  Costa Rica earthquake  2012-09-04        13  Costa Rica
# 2  Costa Rica earthquake  2012-09-04        13  Costa Rica
# 3  Costa Rica earthquake  2012-09-04        13  Costa Rica
# 4  Costa Rica earthquake  2012-09-04        13  Costa Rica
#
#   location_description sub_category        type
# 0           Costa Rica  Geophysical  Earthquake
# 1           Costa Rica  Geophysical  Earthquake
# 2           Costa Rica  Geophysical  Earthquake
# 3           Costa Rica  Geophysical  Earthquake
# 4           Costa Rica  Geophysical  Earthquake

# %% [markdown]
# ## Modeling

# %%
# Tokenizer
model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation", #task
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,

    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Load model
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})

# %%
# Prompt Template Formatting
B_INST, E_INST = "[INST]", "[/INST]"
B_SYS, E_SYS = "<>\n", "\n<>\n\n"
DEFAULT_SYSTEM_PROMPT = """\
You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe. Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.

If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information."""

def get_prompt(instruction, new_system_prompt=DEFAULT_SYSTEM_PROMPT ):
    SYSTEM_PROMPT = B_SYS + new_system_prompt + E_SYS
    prompt_template =  B_INST + SYSTEM_PROMPT + instruction + E_INST
    return prompt_template

def parse_text(text):
        wrapped_text = textwrap.fill(text, width=100)
        print(wrapped_text +'\n\n')
        # return assistant_text

# %%
def generate_answer(text, system_prompt, instruction):
  prompt_template = get_prompt(instruction, system_prompt)
  prompt = PromptTemplate(template=prompt_template, input_variables= ['text'])
  llm_chain = LLMChain(prompt=prompt, llm=llm)
  text = llm_chain.run(text)
  return text

# %%
data = {
    'TweetID': [25454],
    'TweetText': ['MT @COEmergency Colorado Avoid main road because its blocked by wildfire'],
    'InformationSource': ['Government'],
    'InformationType': ['Donations and volunteering'],
    'Informativeness Label': ['Related and informative'],
    'Timestamp': ['2013-09-17 10:43:12+00:00'],
    'answer': ['']
}

df = pd.DataFrame(data)
df
# Out:
#    TweetID                                          TweetText  \
# 0    25454  MT @COEmergency Colorado Avoid main road becau...
#
#   InformationSource             InformationType    Informativeness Label  \
# 0        Government  Donations and volunteering  Related and informative
#
#                    Timestamp answer
# 0  2013-09-17 10:43:12+00:00

# %%
# Create a function using the code below to generate a answer for each row in the dataframe. Then apply the function to the dataframe to generate the answer and save the output to 'answer' in df.
def generate_answer(text, system_prompt, instruction):
    # # Define the instruction
    # instruction = instruction + row['TweetText']
    #define the prompt template
    prompt_template = get_prompt(instruction, system_prompt)
    #create prompt
    prompt = PromptTemplate(template=prompt_template, input_variables= ["text"])
    #create the language model chain
    llm_chain = LLMChain(prompt=prompt, llm=llm)
    #generate text using the prompt template
    text = llm_chain.run(text)
    #return the text
    return text

# %%
# Apply the function to the dataframe to generate the answer and save the output to 'answer' in df.
system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer.  Return one word. "
instruction = "Recognize whether this text is in relation to a crisis. If the text is in relation to a crisis, label in one word what is the name of the crisis. Some examples of crisis include [\"Coronavirus\", \"Flood\", \"Earthquake\"]. If no crisis exists, then only answer \"[]\". Return 1 word without explaination. The test is: {text}"

df['answer'] = df.apply(lambda row: generate_answer(row['TweetText'], system_prompt, instruction), axis=1)

# %%
# Check
df.head()
# Out:
#    TweetID                                          TweetText  \
# 0    25454  MT @COEmergency Colorado Avoid main road becau...
#
#   InformationSource             InformationType    Informativeness Label  \
# 0        Government  Donations and volunteering  Related and informative
#
#                    Timestamp  answer
# 0  2013-09-17 10:43:12+00:00    Fire

# %%
# Grab 20 random samples
filtered_df = result_df.query("Label == '2012_Colorado_wildfires'")

testing_df = filtered_df.sample(n=20, random_state=42)
testing_df.columns = testing_df.columns.str.replace(' ', '')

testing_df['TweetText'] = testing_df['TweetText'].astype(str)
# Filter for TweetText string greater than 5 words
testing_df = testing_df[testing_df['TweetText'].str.count(' ').ge(5)]

testing_df.head(20)
# Out:
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type
# 8839  Wildfire
# 8526  Wildfire
# 7762  Wildfire
# 8100  Wildfire
# 8781  Wildfire
# 7984  Wildfire
# 8635  Wildfire
# 8072  Wildfire
# 8516  Wildfire
# 8481  Wildfire
# 7705  Wildfire
# 8510  Wildfire
# 7901  Wildfire
# 7831  Wildfire
# 8184  Wildfire
# 8426  Wildfire
# 8499  Wildfire
# 8084  Wildfire

# %%
import re
# Grab 20 random samples
filtered_df = result_df.query("Label == '2012_Colorado_wildfires'")

testing_df = filtered_df.sample(n=20, random_state=42)
testing_df.columns = testing_df.columns.str.replace(' ', '')

testing_df['TweetText'] = testing_df['TweetText'].astype(str)
# Filter for TweetText string greater than 5 words excluding words starting with "@"" and "http"
testing_df = testing_df[testing_df['TweetText'].str.split().apply(lambda x: sum(1 for word in x if not word.startswith('@') and not word.startswith('http') and not word.startswith('#') )) > 5]
testing_df.head(20)
# Out:
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type
# 8839  Wildfire
# 8526  Wildfire
# 7762  Wildfire
# 8100  Wildfire
# 8781  Wildfire
# 7984  Wildfire
# 8635  Wildfire
# 8072  Wildfire
# 8516  Wildfire
# 8481  Wildfire
# 7705  Wildfire
# 7901  Wildfire
# 7831  Wildfire
# 8184  Wildfire
# 8499  Wildfire
# 8084  Wildfire

# %%
# Running over data

system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer.  Return in max 3 words. "
instruction = "Recognize whether this text is in relation to a crisis. If the text is in relation to a crisis, label in one word what is the name of the crisis. Some examples of crisis include [\"Coronavirus\", \"Flood\", \"Earthquake\"]. If no crisis exists, then only answer \"[]\". Return in max 3 words without explaination. The test is: {text}"

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-56f9ed02174b> in <cell line: 10>()
#      15
#      16     # Update the 'answer' column in the DataFrame using the output from generate_answer
# ---> 17     testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)
#      18
#
# <ipython-input-76-7462861f7bf3> in generate_answer(text, system_prompt, instruction)
#      10     llm_chain = LLMChain(prompt=prompt, llm=llm)
#      11     #generate text using the prompt template
# ---> 12     text = llm_chain.run(text)
#      13     #return the text
#      14     return text
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     499             if len(args) != 1:
#     500                 raise ValueError("`run` supports only one positional argument.")
# --> 501             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     502                 _output_key
#     503             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     304         except BaseException as e:
#     305             run_manager.on_chain_error(e)
# --> 306             raise e
#     307         run_manager.on_chain_end(outputs)
#     308         final_outputs: Dict[str, Any] = self.prep_outputs(
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     298         try:
#     299             outputs = (
# --> 300                 self._call(inputs, run_manager=run_manager)
#     301                 if new_arg_supported
#     302                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#      91         run_manager: Optional[CallbackManagerForChainRun] = None,
#      92     ) -> Dict[str, str]:
# ---> 93         response = self.generate([inputs], run_manager=run_manager)
#      94         return self.create_outputs(response)[0]
#      95
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     101         """Generate LLM result from inputs."""
#     102         prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 103         return self.llm.generate_prompt(
#     104             prompts,
#     105             stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     496     ) -> LLMResult:
#     497         prompt_strings = [p.to_string() for p in prompts]
# --> 498         return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#     499
#     500     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     645                 )
#     646             ]
# --> 647             output = self._generate_helper(
#     648                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     649             )
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     533             for run_manager in run_managers:
#     534                 run_manager.on_llm_error(e)
# --> 535             raise e
#     536         flattened_outputs = output.flatten()
#     537         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/base.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     520         try:
#     521             output = (
# --> 522                 self._generate(
#     523                     prompts,
#     524                     stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/huggingface_pipeline.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     181
#     182             # Process batch of prompts
# --> 183             responses = self.pipeline(batch_prompts)
#     184
#     185             # Process each response in the batch
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     206               ids of the generated text.
#     207         """
# --> 208         return super().__call__(text_inputs, **kwargs)
#     209
#     210     def preprocess(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1119                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1120                 )
# -> 1121                 outputs = list(final_iterator)
#    1122                 return outputs
#    1123             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1044                 with inference_context():
#    1045                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1046                     model_outputs = self._forward(model_inputs, **forward_params)
#    1047                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1048             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     269
#     270         # BS x SL
# --> 271         generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     272         out_b = generated_sequence.shape[0]
#     273         if self.framework == "pt":
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1650
#    1651             # 13. run sample
# -> 1652             return self.sample(
#    1653                 input_ids,
#    1654                 logits_processor=logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2732
#    2733             # forward pass to get next token
# -> 2734             outputs = self(
#    2735                 **model_inputs,
#    2736                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(*args, **kwargs)
#     163                 output = old_forward(*args, **kwargs)
#     164         else:
# --> 165             output = old_forward(*args, **kwargs)
#     166         return module._hf_hook.post_forward(module, output)
#     167
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1036
#    1037         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1038         outputs = self.model(
#    1039             input_ids=input_ids,
#    1040             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     923                 )
#     924             else:
# --> 925                 layer_outputs = decoder_layer(
#     926                     hidden_states,
#     927                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(*args, **kwargs)
#     163                 output = old_forward(*args, **kwargs)
#     164         else:
# --> 165             output = old_forward(*args, **kwargs)
#     166         return module._hf_hook.post_forward(module, output)
#     167
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, padding_mask)
#     633
#     634         # Self Attention
# --> 635         hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     636             hidden_states=hidden_states,
#     637             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(*args, **kwargs)
#     163                 output = old_forward(*args, **kwargs)
#     164         else:
# --> 165             output = old_forward(*args, **kwargs)
#     166         return module._hf_hook.post_forward(module, output)
#     167
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, padding_mask)
#     348         else:
#     349             query_states = self.q_proj(hidden_states)
# --> 350             key_states = self.k_proj(hidden_states)
#     351             value_states = self.v_proj(hidden_states)
#     352
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(*args, **kwargs)
#     158     @functools.wraps(old_forward)
#     159     def new_forward(*args, **kwargs):
# --> 160         args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     161         if module._hf_hook.no_grad:
#     162             with torch.no_grad():
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in pre_forward(self, module, *args, **kwargs)
#     285                         fp16_statistics = self.weights_map[name.replace("weight", "SCB")]
#     286                 set_module_tensor_to_device(
# --> 287                     module, name, self.execution_device, value=self.weights_map[name], fp16_statistics=fp16_statistics
#     288                 )
#     289
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/offload.py in __getitem__(self, key)
#     117
#     118     def __getitem__(self, key):
# --> 119         return self.dataset[f"{self.prefix}{key}"]
#     120
#     121     def __iter__(self):
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/offload.py in __getitem__(self, key)
#     176
#     177             if "dtype" in weight_info:
# --> 178                 return tensor.to(getattr(torch, weight_info["dtype"]))
#     179             else:
#     180                 return tensor
#
# KeyboardInterrupt:

# %%
# Check
testing_df.head(10)
#Print "answer" column in testing_df first row
# print(testing_df['answer'])
# Out:
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type              answer
# 8839  Wildfire    Crisis: Wildfire
# 8526  Wildfire    Crisis: Wildfire
# 7762  Wildfire                  []
# 8100  Wildfire    Crisis: Wildfire
# 7719  Wildfire            Covid-19
# 8781  Wildfire        Crisis: Fire
# 7984  Wildfire                Fire
# 8635  Wildfire    Crisis: Wildfire
# 8072  Wildfire          Crisis: []
# 8516  Wildfire        Crisis: Fire

# %% [markdown]
# ## Experiments

# %%
# crisis information type labels

system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = "Classify the following text for me using these crisis information labels [ \"Caution and advice for residents\", \"Written by Affected individuals \", \"Infrastructure and utilities damage\", \"Soliciting Donations or volunteering to help \", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"]. Return one label without explaination. {text}"

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

    testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
testing_df.head(10)
# Out:
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire                 "Caution and advice for residents"
# 8526  Wildfire                                     Not applicable
# 7762  Wildfire                                     Not applicable
# 8100  Wildfire                                     Not applicable
# 7719  Wildfire                                     Not applicable
# 8781  Wildfire                                     Not applicable
# 7984  Wildfire                                     Not applicable
# 8635  Wildfire    Sure! Based on the given text, the most appr...
# 8072  Wildfire                                     Not applicable
# 8516  Wildfire                                     Not applicable

# %%
# crisis information type labels v2

system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = '''"Classify the following text for me using these crisis information labels [ \"Caution and advice for residents\", \"Affected & individuals\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Below is some example classifications. The format is the text followed by label tag.

1. 390 #HighParkFire evacuees  told they can return home Wednesday http://t.co/cVMgyEwm.
"Affected individuals"

2. Damage Assessment teams for #HighParkFire being assembled to determine what' structures have been burned, damaged or untouched.
"Infrastructure and utilities damage"

3. Sending lots of positive thoughts to Larimer County, Fort Collins and the people affected by the #HighParkFire.
"expressing Sympathy and support for affected"

4. RT @tri1025: RT @LarimerSheriff: #HighParkFire Residents of Red Feather Lakes and Crystal Lakes need to use Cherokee Park Road (CR 80C).
"Caution and advice for residents"

5. BIG Colorado Thank You to @Good4UDrinks for sending more drinks to the frontline.  #HighParkFire http://t.co/sSH2NS2y.
"Donations or volunteering"


Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
testing_df.head(10)
# Out:
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire                             "Affected individuals"
# 8526  Wildfire    Sure, I'd be happy to help! Based on the tex...
# 7762  Wildfire    Sure, I'd be happy to help! Based on the tex...
# 8100  Wildfire    Sure, I can help you with that! Based on the...
# 7719  Wildfire    Sure! Based on the text you provided, the mo...
# 8781  Wildfire    Sure! Based on the text you provided, I woul...
# 7984  Wildfire    Sure, I can help you with that! Based on the...
# 8635  Wildfire    Sure, I can help you with that! Based on the...
# 8072  Wildfire    Sure, I can help you with that! Based on the...
# 8516  Wildfire    Sure! Based on the text you provided, I woul...

# %%
# crisis information type labels v3

system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = '''"Classify the following text for me using these crisis information labels [ \"Caution and advice for residents\", \"Affected & individuals\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Below is some example classifications. The format is the text followed by label tag.

1. 390 #HighParkFire evacuees  told they can return home Wednesday http://t.co/cVMgyEwm.
"Affected individuals"

Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Sure! Based on the text you provided, I woul...
# 8526  Wildfire                             "Affected individuals"
# 7762  Wildfire                             "Affected individuals"
# 8100  Wildfire    Sure, I'd be happy to help! Based on the tex...
# 7719  Wildfire    Sure! Based on the text you provided, I woul...
# 8781  Wildfire                             "Affected individuals"
# 7984  Wildfire                             "Affected individuals"
# 8635  Wildfire    Sure! Based on the text you provided, I woul...
# 8072  Wildfire                             "Affected individuals"
# 8516  Wildfire    Sure, I can help you with that! Based on the...

# %%
# crisis information type labels v4

system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = '''"Classify the following text for me using these crisis information labels [ \"Caution and advice for residents\", \"Affected & individuals\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Sure, I can help you with that! Based on the...
# 8526  Wildfire                             "Affected individuals"
# 7762  Wildfire                                     Not applicable
# 8100  Wildfire                                     Not applicable
# 7719  Wildfire                                     Not applicable
# 8781  Wildfire    Based on the given text, the most appropriat...
# 7984  Wildfire                             "Affected individuals"
# 8635  Wildfire    Sure! Based on the text you provided, I woul...
# 8072  Wildfire                                     Not applicable
# 8516  Wildfire                                     Not applicable

# %%
# crisis information type labels v5

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected & individuals\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                answer
# 8839  Wildfire    "Caution and advice for residents"
# 8526  Wildfire    "Caution and advice for residents"
# 7762  Wildfire                "Affected individuals"
# 8100  Wildfire                        Not applicable
# 7719  Wildfire                "Affected individuals"
# 8781  Wildfire                "Affected individuals"
# 7984  Wildfire                "Affected individuals"
# 8635  Wildfire                "Affected individuals"
# 8072  Wildfire                        Not applicable
# 8516  Wildfire            "Other useful information"

# %%
# crisis information type labels v6

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected & individuals\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Return one label with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Based on the provided text, the most appropr...
# 8526  Wildfire    Based on the provided text, the most appropr...
# 7762  Wildfire    Label: "Not applicable"\nExplanation: This t...
# 8100  Wildfire    Label: "Not applicable"\nExplanation: This t...
# 7719  Wildfire    Label: "Other useful information"\nExplanati...
# 8781  Wildfire    Label: "Affected individuals"\nExplanation: ...
# 7984  Wildfire    Label: "Other useful information"\nExplanati...
# 8635  Wildfire    Label: "Affected individuals"\nExplanation: ...
# 8072  Wildfire    Label: "Not applicable"\nThis text does not ...
# 8516  Wildfire    Label: "Affected individuals"\nExplanation: ...

# %%
# crisis information type labels v7

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected & residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Return one label with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: "Affected & residents"\nExplanation: ...
# 8526  Wildfire    Based on the provided text, the most appropr...
# 7762  Wildfire    Label: "Not applicable"\nExplanation: This t...
# 8100  Wildfire    Label: "Not applicable"\nExplanation: This t...
# 7719  Wildfire    Label: "Affected & residents"\nExplanation: ...
# 8781  Wildfire    Based on the provided text, the most appropr...
# 7984  Wildfire    Label: "Affected & residents"\nExplanation: ...
# 8635  Wildfire    Label: "Affected & residents"\nExplanation: ...
# 8072  Wildfire    Not applicable.\nThis text does not contain ...
# 8516  Wildfire    Label: "Affected & residents"\nExplanation: ...

# %%
# crisis information type labels v8 ***BASELINE*** [with explaination]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
Return one label with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Based on the provided text, the most appropr...
# 8526  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7762  Wildfire    Label: "Not applicable"\nExplanation: This t...
# 8100  Wildfire    Label: "Not applicable"\nThis text does not ...
# 7719  Wildfire    Label: "Other useful information"\nExplanati...
# 8781  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7984  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8635  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8072  Wildfire    Not applicable.\nThis text does not contain ...
# 8516  Wildfire    Label: "Other useful information"\nExplanati...
# 8481  Wildfire    Label: "Other useful information"\nExplanati...
# 7705  Wildfire    Label: "Caution and advice for residents"\nE...
# 7710  Wildfire    Based on the provided text, the most appropr...
# 8510  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7901  Wildfire    Label: "Caution and advice for residents"\nE...
# 7831  Wildfire    Label: "Not applicable"\nThis text does not ...
# 8184  Wildfire    Label: "Not applicable"\nThis text does not ...
# 8426  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8499  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8084  Wildfire    Label: "Affected residents"\nExplanation: Th...

# %%
# crisis information type labels v8 [with list of labels][with explaination in instruction][using this text]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
These labels are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers, companies or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label with explaination using this text: {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: Not applicable\nThis text does not co...
# 8526  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7762  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8100  Wildfire    Label: "Other useful information"\nExplanati...
# 7719  Wildfire    Label: #NotApplicable\nExplanation: This tex...
# 8781  Wildfire    Label: Not applicable\nExplanation: This tex...
# 7984  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8635  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 8072  Wildfire    Not applicable. This text does not contain a...
# 8516  Wildfire    Label: "Other useful information"\nExplanati...

# %%
data = {
    'TweetID': [25454],
    'TweetText': ['This is crazy scary man. http://t.co.uioiohbhbhbhbhbhbhbi #highparkfire'],
    'InformationSource': ['Government'],
    'InformationType': ['Donations and volunteering'],
    'Informativeness Label': ['Related and informative'],
    'Timestamp': ['2013-09-17 10:43:12+00:00'],
    'answer': ['']
}

testing_df = pd.DataFrame(data)
testing_df
# Out:
#    TweetID                                          TweetText  \
# 0    25454  This is crazy scary man. http://t.co.uioiohbhb...
#
#   InformationSource             InformationType    Informativeness Label  \
# 0        Government  Donations and volunteering  Related and informative
#
#                    Timestamp answer
# 0  2013-09-17 10:43:12+00:00

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Return one label with explaination.
"{text}" "'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#    TweetID                                          TweetText  \
# 0    25454  This is crazy scary man. http://t.co.uioiohbhb...
#
#   InformationSource             InformationType    Informativeness Label  \
# 0        Government  Donations and volunteering  Related and informative
#
#                    Timestamp  \
# 0  2013-09-17 10:43:12+00:00
#
#                                               answer
# 0    Label: "Other useful information"\nExplanati...

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks][and few shot examples]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Below is some example classifications. The format is the text followed by label tag:

1. 390 #HighParkFire evacuees  told they can return home Wednesday http://t.co/cVMgyEwm.
"Affected residents"

2. Damage Assessment teams for #HighParkFire being assembled to determine what' structures have been burned, damaged or untouched.
"Infrastructure and utilities damage"

3. Sending lots of positive thoughts to Larimer County, Fort Collins and the people affected by the #HighParkFire.
"expressing Sympathy and support for affected"

4. RT @tri1025: RT @LarimerSheriff: #HighParkFire Residents of Red Feather Lakes and Crystal Lakes need to use Cherokee Park Road (CR 80C).
"Caution and advice for residents"

5. BIG Colorado Thank You to @Good4UDrinks for sending more drinks to the frontline.  #HighParkFire http://t.co/sSH2NS2y.
"Donations or volunteering"

Return one label in quotation marks with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Based on the provided text, the most appropr...
# 8526  Wildfire    Based on the provided text, the most appropr...
# 7762  Wildfire    Based on the text provided, the most appropr...
# 8100  Wildfire    Based on the provided text, the most appropr...
# 7719  Wildfire    "Affected residents"\nThis text contains inf...
# 8781  Wildfire    Based on the given text, the most appropriat...
# 7984  Wildfire    Sure! Based on the given text, I would class...
# 8635  Wildfire    Based on the provided text, the most appropr...
# 8072  Wildfire    "expressing Sympathy and support for affecte...
# 8516  Wildfire    Based on the provided text, the most appropr...
# 8481  Wildfire    Based on the provided text, the most appropr...
# 7705  Wildfire    Based on the given text, the most appropriat...
# 7710  Wildfire    Sure! Based on the given text, the most appr...
# 8510  Wildfire    "Affected residents" - This text contains in...
# 7901  Wildfire    Based on the provided text, the most appropr...
# 7831  Wildfire    Based on the provided text, the most appropr...
# 8184  Wildfire    Based on the provided text, the most appropr...
# 8426  Wildfire    "Affected residents" - This text contains in...
# 8499  Wildfire    "Affected residents" - This text contains in...
# 8084  Wildfire    Based on the provided text, the most appropr...

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks][and few shot examples][remove definitions]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"
"Affected residents"
"Infrastructure and utilities damage"
"Donations or volunteering"
"expressing Sympathy and support for affected"
"other useful information"
"Not applicable"

Below is some example classifications. The format is the text followed by label tag:

1. 390 #HighParkFire evacuees  told they can return home Wednesday http://t.co/cVMgyEwm.
"Affected residents"

2. Damage Assessment teams for #HighParkFire being assembled to determine what' structures have been burned, damaged or untouched.
"Infrastructure and utilities damage"

3. Sending lots of positive thoughts to Larimer County, Fort Collins and the people affected by the #HighParkFire.
"expressing Sympathy and support for affected"

4. RT @tri1025: RT @LarimerSheriff: #HighParkFire Residents of Red Feather Lakes and Crystal Lakes need to use Cherokee Park Road (CR 80C).
"Caution and advice for residents"

5. BIG Colorado Thank You to @Good4UDrinks for sending more drinks to the frontline.  #HighParkFire http://t.co/sSH2NS2y.
"Donations or volunteering"

Return one label in quotation marks with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Based on the text you provided, the most app...
# 8526  Wildfire    "Caution and advice for residents"\nThis tex...
# 7762  Wildfire    Based on the provided text, the most appropr...
# 8100  Wildfire    Based on the text you provided, the most app...
# 7719  Wildfire    Based on the provided text, the most appropr...
# 8781  Wildfire    Based on the text you provided, the most app...
# 7984  Wildfire    "Affected residents"\nThe text mentions the ...
# 8635  Wildfire    Based on the provided text, the most appropr...
# 8072  Wildfire    "Other useful information"\nThe text contain...
# 8516  Wildfire    Based on the text provided, the most appropr...
# 8481  Wildfire    Based on the provided text, the most appropr...
# 7705  Wildfire    Based on the provided text, the most appropr...
# 7710  Wildfire    Based on the text you provided, the most app...
# 8510  Wildfire    "Caution and advice for residents"\nThis tex...
# 7901  Wildfire    Based on the given text, the most appropriat...
# 7831  Wildfire    Based on the provided text, the most appropr...
# 8184  Wildfire    Based on the text you provided, the most app...
# 8426  Wildfire    Based on the provided text, the most appropr...
# 8499  Wildfire    Based on the provided text, the most appropr...
# 8084  Wildfire    Based on the provided text, the most appropr...

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Return one label with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: "Not applicable"\nThis text does not ...
# 8526  Wildfire    Label: "Warnings and advice for residents"\n...
# 7762  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8100  Wildfire    Label: Not applicable\nExplanation: This tex...
# 7719  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8781  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7984  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8635  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 8072  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8516  Wildfire    Label: "Other useful information"\nExplanati...
# 8481  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7705  Wildfire    Label: "Warnings and advice"\nExplanation: T...
# 7710  Wildfire    Based on the text you provided, the most app...
# 8510  Wildfire    Label: Not applicable\nExplanation: This twe...
# 7901  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7831  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8184  Wildfire    Label: Not applicable\nThis tweet does not c...
# 8426  Wildfire    Label: "Other useful information"\nExplanati...
# 8499  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8084  Wildfire    Label: "Affected residents"\nExplanation: Th...

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks][apostrophe around text]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Return one label with explaination. "{text}" "'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: Not applicable\nThis text does not co...
# 8526  Wildfire    Label: "Other useful information"\nExplanati...
# 7762  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8100  Wildfire    Label: Not applicable\nExplanation: This tex...
# 7719  Wildfire    Label: #NotApplicable\nExplanation: The twee...
# 8781  Wildfire    Label: Not applicable\nThis text does not co...
# 7984  Wildfire    Label: Not applicable\nExplanation: This twe...
# 8635  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 8072  Wildfire    Not applicable. This text does not contain a...
# 8516  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8481  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7705  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 7710  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8510  Wildfire    Label: Not applicable\nThis text does not co...
# 7901  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7831  Wildfire    Label: Not applicable\nThis text does not co...
# 8184  Wildfire    Label: Not applicable\nThe text does not con...
# 8426  Wildfire    Label: Not applicable\nExplanation: This twe...
# 8499  Wildfire    Label: "Other useful information"\nExplanati...
# 8084  Wildfire    Label: "Other useful information"\nExplanati...

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks][using this tecxt]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Return one label with explaination using this text:. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: Not applicable\nThis text does not co...
# 8526  Wildfire    Label: "Other useful information"\nExplanati...
# 7762  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8100  Wildfire    Label: Not applicable\nExplanation: This tex...
# 7719  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8781  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7984  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8635  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 8072  Wildfire    Not applicable. This text does not contain a...
# 8516  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8481  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7705  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 7710  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8510  Wildfire    Label: Not applicable\nThis text does not co...
# 7901  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7831  Wildfire    Label: Not applicable\nThis text does not co...
# 8184  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8426  Wildfire    Label: "Other useful information"\nExplanati...
# 8499  Wildfire    Label: "Caution and advice for residents"\nE...
# 8084  Wildfire    Label: Not applicable\nExplanation: This twe...

# %%
# crisis information type labels v9 [with explaination in system prompt][no label list][label in quotation marks][take a deep breathe in system prompt]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Take a deep breath and work on this problem step-by-step. Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Return one label with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: Not applicable\nThis text is not rela...
# 8526  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7762  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8100  Wildfire    Label: Not applicable\nExplanation: This tex...
# 7719  Wildfire    Label: Not applicable\nThis text does not co...
# 8781  Wildfire    Based on the given text, the most appropriat...
# 7984  Wildfire    Label: Not applicable\nExplanation: This tex...
# 8635  Wildfire    Label: "Other useful information"\nExplanati...
# 8072  Wildfire    Not applicable. This text does not contain a...
# 8516  Wildfire    Label: "Other useful information"\nExplanati...
# 8481  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7705  Wildfire    Label: "Caution and advice for residents"\nE...
# 7710  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8510  Wildfire    Label: Not applicable\nThe text does not con...
# 7901  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7831  Wildfire    Based on the given text, the most appropriat...
# 8184  Wildfire    Label: Not applicable\nExplanation: This twe...
# 8426  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8499  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8084  Wildfire    Label: "Affected residents"\nExplanation: Th...

# %%
# crisis information type labels v9 [no explaination in system prompt][no label list][label not in quotation marks]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire                                     Not applicable
# 8526  Wildfire                                     Not applicable
# 7762  Wildfire                                     Not applicable
# 8100  Wildfire                                     Not applicable
# 7719  Wildfire                                     Not applicable
# 8781  Wildfire                                     Not applicable
# 7984  Wildfire                                    Not applicable.
# 8635  Wildfire                                     Not applicable
# 8072  Wildfire                                     Not applicable
# 8516  Wildfire                   Caution and advice for residents
# 8481  Wildfire                                     Not applicable
# 7705  Wildfire                                     Not applicable
# 7710  Wildfire                   Caution and advice for residents
# 8510  Wildfire                                     Not applicable
# 7901  Wildfire                                              Alert
# 7831  Wildfire                                     Not applicable
# 8184  Wildfire                                     Not applicable
# 8426  Wildfire    Based on the provided text, I would classify...
# 8499  Wildfire                                     Not applicable
# 8084  Wildfire                                     Not applicable

# %%
# crisis information type labels v9 [no explaination in system prompt][no label list][label not in quotation marks][asking model to breathe]

system_prompt = "Take a deep breath and work on this problem step-by-step. You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Based on the given text, the most appropriat...
# 8526  Wildfire    Based on the provided text, the most appropr...
# 7762  Wildfire    Based on the given text, the most appropriat...
# 8100  Wildfire    Based on the given text, the most appropriat...
# 7719  Wildfire    Based on the provided text, the most appropr...
# 8781  Wildfire    Based on the provided text, the most appropr...
# 7984  Wildfire    Based on the given text, the most appropriat...
# 8635  Wildfire    Based on the provided text, the most appropr...
# 8072  Wildfire                                     Not applicable
# 8516  Wildfire    Based on the given text, the most appropriat...
# 8481  Wildfire    Based on the given text, the most appropriat...
# 7705  Wildfire    Based on the given text, the most appropriat...
# 7710  Wildfire    Based on the provided text, I would classify...
# 8510  Wildfire                                     Not applicable
# 7901  Wildfire    Based on the provided text, the most appropr...
# 7831  Wildfire    Based on the provided text, the most appropr...
# 8184  Wildfire    Based on the provided text, the most appropr...
# 8426  Wildfire    Based on the provided text, the most appropr...
# 8499  Wildfire    Based on the given text, the most appropriat...
# 8084  Wildfire    Based on the provided text, the most appropr...
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# crisis information type labels v9 [no explaination in system prompt][no label list][label not in quotation marks][asking model to breathe][answer with quotation marks]

system_prompt = "Take a deep breath and work on this problem step-by-step. You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label in quotation marks without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Based on the given text, the most appropriat...
# 8526  Wildfire    Based on the provided text, the most appropr...
# 7762  Wildfire    Sure! Based on the given text, the most appr...
# 8100  Wildfire                              Label: Not applicable
# 7719  Wildfire    Not applicable. #telluride #colorado #landsc...
# 8781  Wildfire                                   "Not applicable"
# 7984  Wildfire    Based on the provided text, the most appropr...
# 8635  Wildfire    Based on the given text, the most appropriat...
# 8072  Wildfire                                    Not applicable.
# 8516  Wildfire    Based on the provided text, the most appropr...
# 8481  Wildfire    Based on the provided text, the most appropr...
# 7705  Wildfire                                   "Not applicable"
# 7710  Wildfire                                   "Not applicable"
# 8510  Wildfire    Based on the text provided, the most appropr...
# 7901  Wildfire                               "Affected residents"
# 7831  Wildfire    Based on the given text, the most appropriat...
# 8184  Wildfire    Based on the provided text, the most appropr...
# 8426  Wildfire    Based on the provided text, the most appropr...
# 8499  Wildfire    Sure, I can help you with that! Based on the...
# 8084  Wildfire    Based on the given text, the most appropriat...

# %%
# crisis information type labels v9 [without explanation][no more label list][label in quotation marks] (seems to have returned random labels)

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels which are defined as follows:
"Caution and advice for residents"= Warnings issues or lifted, guidance, and tips.
"Affected residents"= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
"Infrastructure and utilities damage"= Buildings or roads damaged or operational; utilities/services interrupted or restored.
"Donations or volunteering"= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
"expressing Sympathy and support for affected"= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
"other useful information"= Other information that is useful to a crisis.
"Not applicable"= No information related to a crisis.

Return one label without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                       answer
# 8839  Wildfire               Not applicable
# 8526  Wildfire              Warnings/Issues
# 7762  Wildfire               Not applicable
# 8100  Wildfire               Not applicable
# 7719  Wildfire               Not applicable
# 8781  Wildfire               Not applicable
# 7984  Wildfire              Not applicable.
# 8635  Wildfire              Warnings/Issues
# 8072  Wildfire               Not applicable
# 8516  Wildfire              Warnings/Issues
# 8481  Wildfire               Not applicable
# 7705  Wildfire              Warnings/Issues
# 7710  Wildfire    Warnings issues or lifted
# 8510  Wildfire               Not applicable
# 7901  Wildfire    Warnings issues or lifted
# 7831  Wildfire               Not applicable
# 8184  Wildfire               Not applicable
# 8426  Wildfire               Not applicable
# 8499  Wildfire               Not applicable
# 8084  Wildfire               Not applicable

# %%
# crisis information type labels v8 (without explanation) [without explanation]twice and with label list]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
These labels are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers, companies or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label in without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire                   Caution and advice for residents
# 8526  Wildfire                   Caution and advice for residents
# 7762  Wildfire                                     Not applicable
# 8100  Wildfire                                     Not applicable
# 7719  Wildfire                                     Not applicable
# 8781  Wildfire                                     Not applicable
# 7984  Wildfire                                     Not applicable
# 8635  Wildfire                 "Caution and advice for residents"
# 8072  Wildfire                                     Not applicable
# 8516  Wildfire                                     Not applicable
# 8481  Wildfire    Sure! Based on the given text, I would class...
# 7705  Wildfire                   Caution and advice for residents
# 7710  Wildfire                   Caution and advice for residents
# 8510  Wildfire                                     Not applicable
# 7901  Wildfire                   Caution and advice for residents
# 7831  Wildfire                                     Not applicable
# 8184  Wildfire                                     Not applicable
# 8426  Wildfire                   Caution and advice for residents
# 8499  Wildfire                   Caution and advice for residents
# 8084  Wildfire    Sure, I can help you with that! Based on the...

# %%
# crisis information type labels v8 (without explanation) [without explanation]twice] and with label list][ask for labels in quation marks]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
These labels are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers, companies or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label in quotation marks without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                answer
# 8839  Wildfire                      "Not applicable"
# 8526  Wildfire    "Caution and advice for residents"
# 7762  Wildfire                      "Not applicable"
# 8100  Wildfire                      "Not applicable"
# 7719  Wildfire                      "Not applicable"
# 8781  Wildfire                      "Not applicable"
# 7984  Wildfire                      "Not applicable"
# 8635  Wildfire    "Caution and advice for residents"
# 8072  Wildfire                        Not applicable
# 8516  Wildfire            "Other useful information"
# 8481  Wildfire                  "Affected residents"
# 7705  Wildfire    "Caution and advice for residents"
# 7710  Wildfire    "Caution and advice for residents"
# 8510  Wildfire                      "Not applicable"
# 7901  Wildfire                  "Affected residents"
# 7831  Wildfire                      "Not applicable"
# 8184  Wildfire                      "Not applicable"
# 8426  Wildfire                  "Affected residents"
# 8499  Wildfire    "Caution and advice for residents"
# 8084  Wildfire                  "Affected residents"

# %%
# crisis information type labels v8 (without explanation v2) [without explanation]once] and with label list][ask for labels in quotation marks]

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
These labels are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers, companies or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label in quation marks without explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
# 8481  218150272508235777  RT @tryonb: Chapel Hills Mall in Colorado Spri...
# 7705  211964198396231680  RT @HumaneSociety If you are evacuating please...
# 7710  211991952135172098   This is crazy #highparkfire http://t.co/TJyXcdNN
# 8510  218199391998181376  RT @tannerdsilva: Colorado Springs, my hometow...
# 7901  214426300994162688  RT @coloradoan: #HighParkFire UPDATE: Re-Evacu...
# 7831  213121226510565376  New post: NEW POLL: High Support for Marijuana...
# 8184  217796789141643265  RT @PatrickSandusky: This is colorado springs ...
# 8426  218074875716313090  Colorado Fires... Flying W - http://t.co/aXxRL...
# 8499  218178244329996289  Monster Colorado wildfire rages; Obama plans v...
# 8084  217237688426823680  Praying hard. RT@DenverWestword: High Park fir...
#
#      InformationSource               InformationType          Informativeness  \
# 8839             Media    Donations and volunteering  Related and informative
# 8526         Outsiders      Other Useful Information  Related and informative
# 7762       Not labeled                   Not labeled              Not related
# 8100       Not labeled                   Not labeled              Not related
# 7719       Not labeled                   Not labeled              Not related
# 8781             Media      Other Useful Information  Related and informative
# 7984        Government      Other Useful Information  Related and informative
# 8635              NGOs    Donations and volunteering  Related and informative
# 8072       Not labeled                   Not labeled              Not related
# 8516         Outsiders      Other Useful Information  Related and informative
# 8481          Business      Other Useful Information  Related and informative
# 7705              NGOs            Caution and advice  Related and informative
# 7710         Outsiders      Other Useful Information  Related and informative
# 8510       Not labeled                   Not labeled              Not related
# 7901             Media            Caution and advice  Related and informative
# 7831       Not labeled                   Not labeled              Not related
# 8184         Outsiders          Affected individuals  Related and informative
# 8426         Outsiders      Other Useful Information  Related and informative
# 8499             Media      Other Useful Information  Related and informative
# 8084         Outsiders  Infrastructure and utilities  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
# 8481  2012_Colorado_wildfires 2012-06-28 01:14:12+00:00  Colorado wildfires
# 7705  2012_Colorado_wildfires 2012-06-10 23:32:57+00:00  Colorado wildfires
# 7710  2012_Colorado_wildfires 2012-06-11 01:23:15+00:00  Colorado wildfires
# 8510  2012_Colorado_wildfires 2012-06-28 04:29:23+00:00  Colorado wildfires
# 7901  2012_Colorado_wildfires 2012-06-17 18:36:28+00:00  Colorado wildfires
# 7831  2012_Colorado_wildfires 2012-06-14 04:10:34+00:00  Colorado wildfires
# 8184  2012_Colorado_wildfires 2012-06-27 01:49:35+00:00  Colorado wildfires
# 8426  2012_Colorado_wildfires 2012-06-27 20:14:36+00:00  Colorado wildfires
# 8499  2012_Colorado_wildfires 2012-06-28 03:05:21+00:00  Colorado wildfires
# 8084  2012_Colorado_wildfires 2012-06-25 12:47:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
# 8481  2012-06-08        31      US             Colorado  Climatological
# 7705  2012-06-08        31      US             Colorado  Climatological
# 7710  2012-06-08        31      US             Colorado  Climatological
# 8510  2012-06-08        31      US             Colorado  Climatological
# 7901  2012-06-08        31      US             Colorado  Climatological
# 7831  2012-06-08        31      US             Colorado  Climatological
# 8184  2012-06-08        31      US             Colorado  Climatological
# 8426  2012-06-08        31      US             Colorado  Climatological
# 8499  2012-06-08        31      US             Colorado  Climatological
# 8084  2012-06-08        31      US             Colorado  Climatological
#
#           type                                answer
# 8839  Wildfire                      "Not applicable"
# 8526  Wildfire                  "Affected residents"
# 7762  Wildfire                        Not applicable
# 8100  Wildfire                        Not applicable
# 7719  Wildfire                       Not applicable.
# 8781  Wildfire                      "Not applicable"
# 7984  Wildfire                       Not applicable.
# 8635  Wildfire    "Caution and advice for residents"
# 8072  Wildfire                        Not applicable
# 8516  Wildfire                        Not applicable
# 8481  Wildfire                  "Affected residents"
# 7705  Wildfire    "Caution and advice for residents"
# 7710  Wildfire                      "Not applicable"
# 8510  Wildfire                       Not applicable.
# 7901  Wildfire    "Caution and advice for residents"
# 7831  Wildfire                        Not applicable
# 8184  Wildfire                        Not applicable
# 8426  Wildfire                       Not applicable.
# 8499  Wildfire                      "Not applicable"
# 8084  Wildfire                  "Affected residents"

# %%
# crisis information type labels v8 (seems to be worst for airforce cadtets)

system_prompt = "You are a crisis researcher that excels at classifying whether the text contains useful information in relation to a crisis. Stop after giving one answer. Only return one label that is the most appropriate. "
instruction = '''"Classify the following text using these following labels [ \"Caution and advice for residents\", \"Affected residents\", \"Infrastructure and utilities damage\", \"Donations or volunteering\", \"expressing Sympathy and support for affected\", \"other useful information\", \"Not applicable\"].
These labels are defined as follows:
Caution and advice for residents= Warnings issues or lifted, guidance, and tips.
Affected residents= Casualties due to the crisis. Questions and/or reports about missing, trapped, displaced, evacuated or found people.
Infrastructure and utilities damage= Buildings or roads damaged or operational; utilities/services interrupted or restored.
Donations or volunteering= Needs or donations of supplies such as food, water, clothing, medical supplies or blood. Services needed or offered by volunteers or professionals.
expressing Sympathy and support for affected= Status updates about individuals or loved ones; emotional support, thoughts and prayers.
other useful information= Other information that is useful to a crisis.
Not applicable= No information related to a crisis.

Return one label with explaination. {text}"'''

# Create an empty 'answer' column in testing_df
testing_df['answer'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Generate the prompt
    # prompt_template = get_prompt(instruction, system_prompt)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'answer'] = generate_answer(TweetText, system_prompt, instruction)

testing_df.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                  TweetID                                          TweetText  \
# 8839  221503954108940290  PetMeds Joins Efforts to Help Pets Affected by...
# 8526  218318321509085185  Federal firefighters go uninsured: As brutal w...
# 7762  212412775027314690  So proud of the Colorado Springs Air Force gra...
# 8100  217406194590035968  I couldn't remember what happened to R.J. on #...
# 7719  212056699572469760  #telluride #colorado #landscape  http://t.co/Y...
# 8781  220307872813285376  Anti-Tax movement region of Colorado hit by fi...
# 7984  215821620097462272  USFS forest ecologist: Not just forests out of...
# 8635  218692809920749572  Colorado Fire Relief benefit concerts at Red R...
# 8072  217059048850325504  Lady, in her favorite perch above the backyard...
# 8516  218229725229887488  @KleinErin seems there are heaps of plane issu...
#
#      InformationSource             InformationType          Informativeness  \
# 8839             Media  Donations and volunteering  Related and informative
# 8526         Outsiders    Other Useful Information  Related and informative
# 7762       Not labeled                 Not labeled              Not related
# 8100       Not labeled                 Not labeled              Not related
# 7719       Not labeled                 Not labeled              Not related
# 8781             Media    Other Useful Information  Related and informative
# 7984        Government    Other Useful Information  Related and informative
# 8635              NGOs  Donations and volunteering  Related and informative
# 8072       Not labeled                 Not labeled              Not related
# 8516         Outsiders    Other Useful Information  Related and informative
#
#                         Label                 Timestamp                name  \
# 8839  2012_Colorado_wildfires 2012-07-07 07:20:32+00:00  Colorado wildfires
# 8526  2012_Colorado_wildfires 2012-06-28 12:21:58+00:00  Colorado wildfires
# 7762  2012_Colorado_wildfires 2012-06-12 05:15:26+00:00  Colorado wildfires
# 8100  2012_Colorado_wildfires 2012-06-25 23:57:30+00:00  Colorado wildfires
# 7719  2012_Colorado_wildfires 2012-06-11 05:40:31+00:00  Colorado wildfires
# 8781  2012_Colorado_wildfires 2012-07-04 00:07:44+00:00  Colorado wildfires
# 7984  2012_Colorado_wildfires 2012-06-21 15:00:58+00:00  Colorado wildfires
# 8635  2012_Colorado_wildfires 2012-06-29 13:10:03+00:00  Colorado wildfires
# 8072  2012_Colorado_wildfires 2012-06-25 00:58:04+00:00  Colorado wildfires
# 8516  2012_Colorado_wildfires 2012-06-28 06:29:55+00:00  Colorado wildfires
#
#        start_day  duration country location_description    sub_category  \
# 8839  2012-06-08        31      US             Colorado  Climatological
# 8526  2012-06-08        31      US             Colorado  Climatological
# 7762  2012-06-08        31      US             Colorado  Climatological
# 8100  2012-06-08        31      US             Colorado  Climatological
# 7719  2012-06-08        31      US             Colorado  Climatological
# 8781  2012-06-08        31      US             Colorado  Climatological
# 7984  2012-06-08        31      US             Colorado  Climatological
# 8635  2012-06-08        31      US             Colorado  Climatological
# 8072  2012-06-08        31      US             Colorado  Climatological
# 8516  2012-06-08        31      US             Colorado  Climatological
#
#           type                                             answer
# 8839  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 8526  Wildfire    Label: "Affected residents"\nExplanation: Th...
# 7762  Wildfire    Label: "expressing Sympathy and support for ...
# 8100  Wildfire    Label: Expressing Sympathy and Support for A...
# 7719  Wildfire    Label: Other useful information\nExplanation...
# 8781  Wildfire    Based on the provided text, the most appropr...
# 7984  Wildfire    Label: Other useful information\nExplanation...
# 8635  Wildfire    Label: "Donations or volunteering"\nExplanat...
# 8072  Wildfire    Label: Not applicable\nExplanation: This twe...
# 8516  Wildfire    Label: "Other useful information"\nExplanati...

# %% [markdown]
# ## Performance Evaluation

# %% [markdown]
# # Test
