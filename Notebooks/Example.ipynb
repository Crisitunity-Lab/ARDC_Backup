# %% [markdown]
# # Downloading content from CrisisLex26
# Instead of relying on manually downloading data from CrisisLexT26 this repo can help.
#
# ### Step 1 - Clone this repo
# Clone this repo to retrieve required files and functions.

# %%
user = "Crisitunity-Lab"
repo = "ARDC-Project"

# !git clone https://github.com/$user/$repo /content/repo
# Out:
# Cloning into '/content/repo'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 348 (delta 73), reused 75 (delta 30), pack-reused 199
# Receiving objects: 100% (348/348), 1.58 MiB | 10.42 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %% [markdown]
# # Step 2 Install requirements
# Using pip install the library requirements into the Colab Notebook

# %%
# !pip install -r /content/repo/requirements.txt
# Out:
# Collecting pandas==2.1.1 (from -r /content/repo/requirements.txt (line 1))
#   Downloading pandas-2.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 51.7 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/repo/requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.1->-r /content/repo/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.1->-r /content/repo/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.1->-r /content/repo/requirements.txt (line 1)) (2023.3.post1)
# Collecting tzdata>=2022.1 (from pandas==2.1.1->-r /content/repo/requirements.txt (line 1))
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 2)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0->-r /content/repo/requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.1->-r /content/repo/requirements.txt (line 1)) (1.16.0)
# Installing collected packages: tzdata, pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.1 which is incompatible.
# Successfully installed pandas-2.1.1 tzdata-2023.3

# %% [markdown]
# # Step 3 Import Data Utils and get data
# Using the pre-built function in the data utils file, provide a link to the zipped data and a destination for the data to be unzippe too.

# %%
import repo.src.structure_extractor.data_utils as du

zip_file_url = "https://github.com/sajao/CrisisLex/blob/master/releases/CrisisLexT26-v1.0.zip?raw=true"
dest_folder = "/content/data/"

du.unzip_from_url(src=zip_file_url, dest=dest_folder)
# Out:
# Download and Unzip complete

# %% [markdown]
# Data is now stored at /content/data/CrisisLexT26 within the colab environment.
#
# # Data Frame
# To get the data into a dataframe - there's a function for that.

# %%
# Set the folder name for where the data is stored
data_folder_name = "CrisisLexT26"
data_loc = dest_folder + data_folder_name
min_tweet_length = 6

# Combine csv's into a single dataframe. By default the folder the data is stored in is included as a
# new field called "label", but this can be turned off by setting the retrieve_label parameter to False.
df = du.combine_csv_files(data_loc, min_tweet_len=min_tweet_length)
# Out:
# /content/repo/src/structure_extractor/data_utils.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_df["label"]=label

# %%
# Data is now in a nice dataframe
df.head(10)
# Out:
#               Tweet ID                                         Tweet Text  \
# 2   272772643160219648  a Mãe do meu amigo #Pablo. morreu :( ta muito ...
# 4   272806969348337664  11-26-12 | E-Games Attendant | Chada Bingo Hou...
# 6   272859754689351680  St Scholastica's College, Manila suspends clas...
# 8   273116454486949888  En el curso de primeros auxilios con @mvallvey...
# 10  273852441563394049  RT @ChandlerGalt: Why CIOs May Morph Into the ...
# 11  273870380622573568  #pablo,o vienes ya o te quedas sin hermana a c...
# 12  273888676151427072  Quiero que #Clemente le diga lo que le dijo la...
# 14  273906728473608194  RT @jcordon5: Esperan su oportunidad en el ban...
# 16  274248320958996480  RT @ZaniniGermano: #Forgreen LIfe.Il mio plaus...
# 17  274275105788542976  Je viens de voir la #PP de #Pablo ! En Mode Te...
#
#    Information Source    Information Type          Informativeness  \
# 2         Not labeled         Not labeled              Not related
# 4         Not labeled         Not labeled              Not related
# 6                NGOs  Caution and advice  Related and informative
# 8         Not labeled         Not labeled           Not applicable
# 10        Not labeled         Not labeled              Not related
# 11        Not labeled         Not labeled           Not applicable
# 12        Not labeled         Not labeled              Not related
# 14        Not labeled         Not labeled           Not applicable
# 16        Not labeled         Not labeled           Not applicable
# 17        Not labeled         Not labeled           Not applicable
#
#                  label  year country_code crisis_type
# 2   2012_Typhoon_Pablo  2012           PH     Typhoon
# 4   2012_Typhoon_Pablo  2012           PH     Typhoon
# 6   2012_Typhoon_Pablo  2012           PH     Typhoon
# 8   2012_Typhoon_Pablo  2012           PH     Typhoon
# 10  2012_Typhoon_Pablo  2012           PH     Typhoon
# 11  2012_Typhoon_Pablo  2012           PH     Typhoon
# 12  2012_Typhoon_Pablo  2012           PH     Typhoon
# 14  2012_Typhoon_Pablo  2012           PH     Typhoon
# 16  2012_Typhoon_Pablo  2012           PH     Typhoon
# 17  2012_Typhoon_Pablo  2012           PH     Typhoon
