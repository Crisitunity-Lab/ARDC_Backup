# %% [markdown]
# <a href="https://colab.research.google.com/github/Crisitunity-Lab/ARDC-Project/blob/main/Notebooks/Llama2_prod_r6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Llama2 Production
#
# SUMA 08/10/2023

# %% [markdown]
# #Instructions
#
# Running code on Google Colab
# 1.   Create HuggingFace account
# 2.   Gain access to model: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf
# 3.   Create folder 'data' in project folder on personal Google Drive
# 4.   Save data set CrisiLexT26 in folder 'data'
# 5.   Data sourced from: https://crisislex.org/data-collections.html#CrisisLexT26
# 6.   Mount Google Drive
# 7.   Update code with Paths
# 8.   Set system up as per steps below
# 9.   Run Experiments
# 10.  Evaluate

# %% [markdown]
# ## Setup

# %%
# Install packages
# !pip install -q transformers einops accelerate langchain bitsandbytes
# !pip install sentencepiece
# !pip install pycountry
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 65.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 91.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 76.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.5 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.4 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 26.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry) (67.7.2)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681833 sha256=0c0b649705f50bef11279d44efb787188960bb60b9c371d9fccfb4262c8451fb
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
# Import Packages
from langchain import PromptTemplate,  LLMChain
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer
import transformers
import torch
import pandas as pd
import numpy as np
import json
import os
import csv
import time
import re
import matplotlib.pyplot as plt
import json
import pycountry

# %%
# Mounting GDrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Prerequisites
#
# To load our desired model, `meta-llama/Llama-2-7b-chat-hf`, we first need to authenticate ourselves on Hugging Face. This ensures we have the correct permissions to fetch the model.
#
# 1. Gain access to the model on Hugging Face: [Link](https://huggingface.co/meta-llama/Llama-2-7b-chat-hf).
# 2. Use the Hugging Face CLI to login and verify your authentication status.

# %%
# Logging onto HuggingFace
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## Preparing data

# %%
# Read (timestamps)

# Path to the main folder
main_folder = '/content/gdrive/MyDrive/iLab2/data/CrisisLexT26'

# Function to process CSV files in a folder
def process_folder(folder_path):
    dfs = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.csv') and 'period' in file.lower():
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                dfs.append(df)
    return dfs

# Read and process each subfolder
combined_data = []
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)
    if os.path.isdir(subfolder_path):
        subfolder_data = process_folder(subfolder_path)
        combined_data.extend(subfolder_data)

# Concatenate all data into one DataFrame
combined_df_p = pd.concat(combined_data, ignore_index=True)


# Remove spaces from column names
combined_df_p.columns = combined_df_p.columns.str.replace(' ', '')

# Rename Columns in prep for left join
combined_df_p.rename(columns={'Tweet-ID': 'Tweet ID'}, inplace=True)

# # Save the combined DataFrame to a CSV file
# output_file = 'combined_data.csv'
# combined_df.to_csv(output_file, index=False)

print(f"Combined timestamps read")
# Out:
# Combined timestamps read

# %%
# Read tweets

# Path to the main folder
main_folder = '/content/gdrive/MyDrive/iLab2/data/CrisisLexT26'

# Function to process CSV files in a folder, add folder name as label, and add subfolder name as a column
def process_folder(folder_path, label, subfolder_name):
    dfs = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.csv') and 'labeled' in file.lower():
                file_path = os.path.join(root, file)
                df = pd.read_csv(file_path)
                df['Label'] = label
                df['subfolder_name'] = subfolder_name  # Add subfolder name as a column
                dfs.append(df)
    return dfs

# Read and process each subfolder
combined_data = []
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)
    if os.path.isdir(subfolder_path):
        label = subfolder
        subfolder_data = process_folder(subfolder_path, label, subfolder)
        combined_data.extend(subfolder_data)

# Concatenate all data into one DataFrame
combined_df_l = pd.concat(combined_data, ignore_index=True)

# Print the first few rows of the combined DataFrame
print(f"Combined tweets read")
combined_df_l.head(10)
# Out:
# Combined tweets read
#              Tweet ID                                         Tweet Text  \
# 0  347686624563429378  RT @CBCAlerts: Canmore, Alta. declares state o...
# 1  347766337344503808  RT @GlobalCalgary: If you are in #Canmore and ...
# 2  347779159327637504  RT @metrocalgary: UPDATE: Latest from the @cit...
# 3  347783236191129600  RT @GlobalCalgary: GALLERY: Incredible photos ...
# 4  347793432514801665  RT @nenshi: Major risk of flooding in Calgary....
# 5  347793818403344384  RT @weathernetwork: RT: Residents of #HighRive...
# 6  347802211222433792  RT @BrockWHarrison: . @ElectDanielle and other...
# 7  347804916514951168  Lots of #abflood updates on our liveblog http:...
# 8  347808955663257600  RT @aldjohnmar: Our first Emergency Shelter wi...
# 9  347812738900320256  'Move to high ground:' Rapid flooding forces e...
#
#    Information Source              Information Type          Informativeness  \
# 0               Media          Affected individuals  Related and informative
# 1               Media            Caution and advice  Related and informative
# 2          Government            Caution and advice  Related and informative
# 3               Media                Not applicable  Related and informative
# 4          Government            Caution and advice  Related and informative
# 5               Media          Affected individuals  Related and informative
# 6                NGOs          Affected individuals  Related and informative
# 7               Media      Other Useful Information  Related and informative
# 8                NGOs  Infrastructure and utilities  Related and informative
# 9               Media            Caution and advice  Related and informative
#
#                  Label       subfolder_name
# 0  2013_Alberta_floods  2013_Alberta_floods
# 1  2013_Alberta_floods  2013_Alberta_floods
# 2  2013_Alberta_floods  2013_Alberta_floods
# 3  2013_Alberta_floods  2013_Alberta_floods
# 4  2013_Alberta_floods  2013_Alberta_floods
# 5  2013_Alberta_floods  2013_Alberta_floods
# 6  2013_Alberta_floods  2013_Alberta_floods
# 7  2013_Alberta_floods  2013_Alberta_floods
# 8  2013_Alberta_floods  2013_Alberta_floods
# 9  2013_Alberta_floods  2013_Alberta_floods

# %%
# Extract earliest timestamp

# Convert it to datetime first
combined_df_p['Timestamp'] = pd.to_datetime(combined_df_p['Timestamp'])

# Group by 'Tweet-ID' and aggregate to find the earliest timestamp
earliest_timestamps = combined_df_p.groupby('Tweet ID')['Timestamp'].agg('min').reset_index()

# Display or use the resulting DataFrame 'earliest_timestamps'
# print(earliest_timestamps)

# %%
# Left join

# Perform a left join on 'Tweet ID'
result_df = combined_df_l.merge(earliest_timestamps, on='Tweet ID', how='left')

# Display
# print(result_df)
# result_df.shape
result_df.head()
# Out:
#              Tweet ID                                         Tweet Text  \
# 0  347686624563429378  RT @CBCAlerts: Canmore, Alta. declares state o...
# 1  347766337344503808  RT @GlobalCalgary: If you are in #Canmore and ...
# 2  347779159327637504  RT @metrocalgary: UPDATE: Latest from the @cit...
# 3  347783236191129600  RT @GlobalCalgary: GALLERY: Incredible photos ...
# 4  347793432514801665  RT @nenshi: Major risk of flooding in Calgary....
#
#    Information Source      Information Type          Informativeness  \
# 0               Media  Affected individuals  Related and informative
# 1               Media    Caution and advice  Related and informative
# 2          Government    Caution and advice  Related and informative
# 3               Media        Not applicable  Related and informative
# 4          Government    Caution and advice  Related and informative
#
#                  Label       subfolder_name                 Timestamp
# 0  2013_Alberta_floods  2013_Alberta_floods 2013-06-20 12:05:25+00:00
# 1  2013_Alberta_floods  2013_Alberta_floods 2013-06-20 17:22:10+00:00
# 2  2013_Alberta_floods  2013_Alberta_floods 2013-06-20 18:13:07+00:00
# 3  2013_Alberta_floods  2013_Alberta_floods 2013-06-20 18:29:19+00:00
# 4  2013_Alberta_floods  2013_Alberta_floods 2013-06-20 19:09:50+00:00

# %%
# Read

# Define the main folder path
main_folder = '/content/gdrive/MyDrive/iLab2/data/CrisisLexT26'

# Initialize empty lists to store the extracted data
subfolder_names = []
names = []
start_days = []
durations = []
countries = []
location_descriptions = []
sub_categories = []
types = []

# Loop through the subfolders
for subfolder in os.listdir(main_folder):
    subfolder_path = os.path.join(main_folder, subfolder)

    # Check if it's a directory
    if os.path.isdir(subfolder_path):
        json_files = [f for f in os.listdir(subfolder_path) if f.endswith('.json')]

        # Loop through JSON files in the subfolder
        for json_file in json_files:
            json_path = os.path.join(subfolder_path, json_file)

            # Read the JSON file
            with open(json_path, 'r') as f:
                data = json.load(f)

                # Extract the required information
                subfolder_names.append(subfolder)
                names.append(data['name'])
                start_days.append(data['time']['start_day'])
                durations.append(data['time']['duration'])
                countries.append(data['location']['country'])
                location_descriptions.append(data['location']['location_description'])
                sub_categories.append(data['categorization']['sub_category'])
                types.append(data['categorization']['type'])

# Create a DataFrame from the extracted data
df_annotation = pd.DataFrame({
    'subfolder_name': subfolder_names,
    'name': names,
    'start_day': start_days,
    'duration': durations,
    'country': countries,
    'location_description': location_descriptions,
    'sub_category': sub_categories,
    'type': types
})

# Display the DataFrame
df_annotation.head()
# Out:
#                   subfolder_name                      name   start_day  \
# 0            2013_Alberta_floods            Alberta Floods  17/06/2013
# 1  2013_Glasgow_helicopter_crash  Glasgow helicopter crash  2013-11-29
# 2     2012_Costa_Rica_earthquake     Costa Rica earthquake  2012-09-04
# 3             2013_Manila_floods             Manila Floods  2013-08-17
# 4      2013_LA_airport_shootings      LA Airport Shootings  2013-11-01
#
#    duration      country location_description   sub_category        type
# 0        25       Canada              Alberta   Hydrological      Floods
# 1        30           UK              Glasgow  Unintentional       Crash
# 2        13   Costa Rica           Costa Rica    Geophysical  Earthquake
# 3        11  Phillipines               Manila   Hydrological      Floods
# 4        12           US          Los Angeles    Intentional   Shootings

# %%
# Left join

# Perform a left join on the 'subfolder'
result_df = result_df.merge(df_annotation, left_on='subfolder_name', right_on='subfolder_name', how='left')

# Drop the duplicate 'subfolder_name'
result_df.drop(columns=['subfolder_name'], inplace=True)

# %%
# Count the number of rows in result_df
row_count = result_df.shape[0]

# Print the row count
print(f"Number of rows in result_df: {row_count}")

result_df.head()
# Out:
# Number of rows in result_df: 27933
#              Tweet ID                                         Tweet Text  \
# 0  347686624563429378  RT @CBCAlerts: Canmore, Alta. declares state o...
# 1  347766337344503808  RT @GlobalCalgary: If you are in #Canmore and ...
# 2  347779159327637504  RT @metrocalgary: UPDATE: Latest from the @cit...
# 3  347783236191129600  RT @GlobalCalgary: GALLERY: Incredible photos ...
# 4  347793432514801665  RT @nenshi: Major risk of flooding in Calgary....
#
#    Information Source      Information Type          Informativeness  \
# 0               Media  Affected individuals  Related and informative
# 1               Media    Caution and advice  Related and informative
# 2          Government    Caution and advice  Related and informative
# 3               Media        Not applicable  Related and informative
# 4          Government    Caution and advice  Related and informative
#
#                  Label                 Timestamp            name   start_day  \
# 0  2013_Alberta_floods 2013-06-20 12:05:25+00:00  Alberta Floods  17/06/2013
# 1  2013_Alberta_floods 2013-06-20 17:22:10+00:00  Alberta Floods  17/06/2013
# 2  2013_Alberta_floods 2013-06-20 18:13:07+00:00  Alberta Floods  17/06/2013
# 3  2013_Alberta_floods 2013-06-20 18:29:19+00:00  Alberta Floods  17/06/2013
# 4  2013_Alberta_floods 2013-06-20 19:09:50+00:00  Alberta Floods  17/06/2013
#
#    duration country location_description  sub_category    type
# 0        25  Canada              Alberta  Hydrological  Floods
# 1        25  Canada              Alberta  Hydrological  Floods
# 2        25  Canada              Alberta  Hydrological  Floods
# 3        25  Canada              Alberta  Hydrological  Floods
# 4        25  Canada              Alberta  Hydrological  Floods

# %% [markdown]
# ## Cleaning

# %%
# Country coding

# Funciton
def clean_country_name(country_name):
    try:
        country = pycountry.countries.get(name=country_name)
        if country:
            return country.alpha_2
        else:
            return "Unknown"
    except LookupError:
        return "Unknown"

# Clean
result_df['country'] = result_df['country'].apply(clean_country_name)

# %%
# Replace underscores
result_df['Label'] = result_df['Label'].str.replace('_', ' ')

# %%
# Show
result_df.head()
# Out:
#              Tweet ID                                         Tweet Text  \
# 0  347686624563429378  RT @CBCAlerts: Canmore, Alta. declares state o...
# 1  347766337344503808  RT @GlobalCalgary: If you are in #Canmore and ...
# 2  347779159327637504  RT @metrocalgary: UPDATE: Latest from the @cit...
# 3  347783236191129600  RT @GlobalCalgary: GALLERY: Incredible photos ...
# 4  347793432514801665  RT @nenshi: Major risk of flooding in Calgary....
#
#    Information Source      Information Type          Informativeness  \
# 0               Media  Affected individuals  Related and informative
# 1               Media    Caution and advice  Related and informative
# 2          Government    Caution and advice  Related and informative
# 3               Media        Not applicable  Related and informative
# 4          Government    Caution and advice  Related and informative
#
#                  Label                 Timestamp            name   start_day  \
# 0  2013 Alberta floods 2013-06-20 12:05:25+00:00  Alberta Floods  17/06/2013
# 1  2013 Alberta floods 2013-06-20 17:22:10+00:00  Alberta Floods  17/06/2013
# 2  2013 Alberta floods 2013-06-20 18:13:07+00:00  Alberta Floods  17/06/2013
# 3  2013 Alberta floods 2013-06-20 18:29:19+00:00  Alberta Floods  17/06/2013
# 4  2013 Alberta floods 2013-06-20 19:09:50+00:00  Alberta Floods  17/06/2013
#
#    duration country location_description  sub_category    type
# 0        25      CA              Alberta  Hydrological  Floods
# 1        25      CA              Alberta  Hydrological  Floods
# 2        25      CA              Alberta  Hydrological  Floods
# 3        25      CA              Alberta  Hydrological  Floods
# 4        25      CA              Alberta  Hydrological  Floods

# %% [markdown]
# ## Model

# %%
def generate_answer(text, system_prompt, instruction):
  promt_template = get_prompt(instruction, system_prompt)
  prompt = PromptTemplate(template=prompt_template, input_variables= ['text'])
  llm_chain = LLMChain(prompt=prompt, llm=llm)
  text = llm_chain.run(text)
  return text

# %%
# Tokenizer
model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation", #task
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    do_sample=True,
    top_k=10,

    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
# Load model
llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})

# %%
# Prompt Template Formatting
B_INST, E_INST = "[INST]", "[/INST]"
B_SYS, E_SYS = "<>\n", "\n<>\n\n"
DEFAULT_SYSTEM_PROMPT = """\
You are a helpful, respectful and honest assistant. Always answer as helpfully as possible, while being safe. Your answers should not include any harmful, unethical, racist, sexist, toxic, dangerous, or illegal content. Please ensure that your responses are socially unbiased and positive in nature.

If a question does not make any sense, or is not factually coherent, explain why instead of answering something not correct. If you don't know the answer to a question, please don't share false information."""

def get_prompt(instruction, new_system_prompt=DEFAULT_SYSTEM_PROMPT ):
    SYSTEM_PROMPT = B_SYS + new_system_prompt + E_SYS
    prompt_template =  B_INST + SYSTEM_PROMPT + instruction + E_INST
    return prompt_template

def parse_text(text):
        wrapped_text = textwrap.fill(text, width=100)
        print(wrapped_text +'\n\n')
        # return assistant_text

# %%
# Create a function using the code below to generate a answer for each row in the dataframe. Then apply the function to the dataframe to generate the answer and save the output to 'answer' in df.
def generate_answer(text, system_prompt, instruction):
    # # Define the instruction
    # instruction = instruction + row['TweetText']
    #define the prompt template
    prompt_template = get_prompt(instruction, system_prompt)
    #create prompt
    prompt = PromptTemplate(template=prompt_template, input_variables= ["text"])
    #create the language model chain
    llm_chain = LLMChain(prompt=prompt, llm=llm)
    #generate text using the prompt template
    text = llm_chain.run(text)
    #return the text
    return text

# %% [markdown]
# ## Experiments

# %%
# Grab 10 random samples
# filtered_df = result_df.query("Label == '2013_Colorado_floods'")
testing_df = result_df.sample(n=50, random_state=42)
testing_df.columns = testing_df.columns.str.replace(' ', '')
testing_df['TweetText'] = testing_df['TweetText'].astype(str)


# testing_df.head(12)

# %%
# Experiment 1: Crisis location code (country)

system_prompt = "You are an advance assistant that excels at analysing text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer. If the text is ambigous return  '''Not applicable'''. Only return one code that is the most appropriate without explaination. Return one label without comment or dialogugue. If the location is a state, return the country in which the state is. "
instruction = "For the following text for me the ISO country code. {text}"

# Create an empty 'answer' column in testing_df
testing_df['country_pred'] = ''

# Loop over the data
for index, row in testing_df.iterrows():
    TweetText = row['TweetText']

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'country_pred'] = generate_answer(TweetText, system_prompt, instruction)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
# Experiment 2: crisis informativeness type labels

system_prompt = "You are an advance assistant that excels at classifying whether the text that contains useful information during or after a crisis. A crisis can include bushfires, wildfires, floods, hurricanes, earthquakes, covid-19, pandemic etc. Stop after giving one answer. If it is not related to a crisis return '''Not applicable'''. Only return one label that is the most appropriate without explaination. Return one label without comment or dialogugue."
instruction = "Classify {TweetText} for me whether it is informatie and whether it is related to {Label}, using these crisis information labels [ \"Related - but not informative\", \"Related and informative\", \"Not related\"]."

# Create an empty 'answer' column in testing_df
testing_df['Informativeness_pred'] = ''

# Loop over the data
for index, row in testing_df.iterrows():

    # Input variables
    input_variables = {
        "TweetText": row['TweetText'],
        "Label": row['Label']
        }

    #define the prompt template
    prompt_template = get_prompt(instruction, system_prompt)

    #create prompt
    prompt = PromptTemplate(template=prompt_template, input_variables= ["TweetText", "Label"])

    #create the language model chain
    llm_chain = LLMChain(prompt=prompt, llm=llm)

    #generate text using the prompt template
    text_inf = llm_chain.run(input_variables)

    # Update the 'answer' column in the DataFrame using the output from generate_answer
    testing_df.loc[index, 'Informativeness_pred'] = text_inf
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(

# %%
# Check
testing_df.head(20)
# Out:
#                   TweetID                                          TweetText  \
# 17799  239986309865807872  RT @garcilasop: #Lafuncióndebecontinuar es una...
# 9419   275898683109801984  Typhoon Bopha Pounds Southern Philippines: A p...
# 1972   412933108561108992  #helicopter #parachute #drop #sarmaaaan http:/...
# 24446  392992116478996481  RT @MarkDiStef: Defence Dept's been investigat...
# 12125  327400365765046272  Tak Ada WNI Korban Runtuhnya Rana Plaza Bangla...
# 27873  404735664329351168  RT @nicola_pinna: A  #Olbia c'è bisogno di cib...
# 2055   415154554549075968  RT @BreahnaZhane: RIP To Our Fort Riley Soldie...
# 15053  390643910214946817  #Earthquake 7.2 tuesday 15 oct destroyed a lot...
# 4667   396330455303475200  RT @jackmooring: Praying for the victims at LA...
# 8365   302496073392459777  RT @TeamCoco: OMG guyz, did you see that meteo...
# 24958  266242464183091200  RT @palabrasvida: Sismo de 7.4 en costas de Gu...
# 5043   396384670847623169  RT @QueenPetraK: Law enforcement sources: #LAX...
# 27606  403141631672475648  Alluvione Sardegna, la testimonianza: ''Ci sia...
# 7602   302312513872211969  http://t.co/X0d2pk1s  #RussianMeteor Buster ex...
# 26296  295693910573993986  RT @KellyDungey: @WynnumHerald from @brisbanes...
# 21370  209380259697659904  RT @rita3870: “@MatitaHB: #terremoto ho sentit...
# 27279  402761514484269056  RT @Corriereit: Alluvione in Sardegna,17 morti...
# 16408  323894581928288258  RT @NoRapist: I know this is not rape related,...
# 9733   276894738026733568       Our God is Greater :) Good Morning! #PabloPH
# 10574  380130451014553600  Noble Energy: Flooding closes 5-10 percent of ...
#
#       InformationSource               InformationType  \
# 17799         Outsiders      Other Useful Information
# 9419              Media            Caution and advice
# 1972        Not labeled                   Not labeled
# 24446         Outsiders            Caution and advice
# 12125             Media                Not applicable
# 27873         Outsiders    Donations and volunteering
# 2055        Not labeled                   Not labeled
# 15053             Media  Infrastructure and utilities
# 4667          Outsiders          Sympathy and support
# 8365              Media                Not applicable
# 24958         Outsiders          Sympathy and support
# 5043              Media          Affected individuals
# 27606        Eyewitness      Other Useful Information
# 7602        Not labeled                   Not labeled
# 26296             Media      Other Useful Information
# 21370         Outsiders          Sympathy and support
# 27279         Outsiders          Affected individuals
# 16408         Outsiders          Affected individuals
# 9733          Outsiders          Sympathy and support
# 10574          Business  Infrastructure and utilities
#
#                      Informativeness                          Label  \
# 17799  Related - but not informative        2012 Venezuela refinery
# 9419         Related and informative             2012 Typhoon Pablo
# 1972                     Not related  2013 Glasgow helicopter crash
# 24446        Related and informative        2013 Australia bushfire
# 12125        Related and informative   2013 Savar building collapse
# 27873        Related and informative           2013 Sardinia floods
# 2055                     Not related  2013 Glasgow helicopter crash
# 15053        Related and informative          2013 Bohol earthquake
# 4667   Related - but not informative      2013 LA airport shootings
# 8365   Related - but not informative             2013 Russia meteor
# 24958        Related and informative      2012 Guatemala earthquake
# 5043         Related and informative      2013 LA airport shootings
# 27606        Related and informative           2013 Sardinia floods
# 7602                     Not related             2013 Russia meteor
# 26296        Related and informative         2013 Queensland floods
# 21370  Related - but not informative         2012 Italy earthquakes
# 27279        Related and informative           2013 Sardinia floods
# 16408  Related - but not informative           2013 Boston bombings
# 9733   Related - but not informative             2012 Typhoon Pablo
# 10574        Related and informative           2013 Colorado floods
#
#                       Timestamp                          name   start_day  \
# 17799 2012-08-27 07:22:49+00:00  Venezuela refinery explosion  2012-08-24
# 9419  2012-12-04 09:45:46+00:00                 Typhoon Pablo  2012-11-24
# 1972  2013-12-17 13:11:39+00:00      Glasgow helicopter crash  2013-11-29
# 24446 2013-10-23 12:33:16+00:00           Australia wildfires  2013-10-12
# 12125 2013-04-25 12:35:04+00:00       Savar building collapse  2013-04-23
# 27873 2013-11-24 22:17:56+00:00               Sardinia Floods  2013-11-16
# 2055  2013-12-23 16:18:53+00:00      Glasgow helicopter crash  2013-11-29
# 15053 2013-10-17 01:02:20+00:00              Bohol earthquake  2013-10-14
# 4667  2013-11-01 17:38:38+00:00          LA Airport Shootings  2013-11-01
# 8365  2013-02-15 19:14:18+00:00                Russian meteor  2013-02-14
# 24958 2012-11-07 18:15:24+00:00          Guatemala earthquake  2012-11-06
# 5043  2013-11-01 21:14:04+00:00          LA Airport Shootings  2013-11-01
# 27606 2013-11-20 12:43:49+00:00               Sardinia Floods  2013-11-16
# 7602  2013-02-15 07:04:54+00:00                Russian meteor  2013-02-14
# 26296 2013-01-28 00:44:56+00:00             Queensland Floods  2013-01-17
# 21370 2012-06-03 20:25:18+00:00             Italy earthquakes  2012-05-18
# 27279 2013-11-19 11:33:22+00:00               Sardinia Floods  2013-11-16
# 16408 2013-04-15 20:24:20+00:00               Boston Bombings  2013-04-15
# 9733  2012-12-07 03:43:44+00:00                 Typhoon Pablo  2012-11-24
# 10574 2013-09-18 00:45:36+00:00               Colorado Floods  2013-09-08
#
#        duration  country location_description    sub_category        type  \
# 17799        12  Unknown               Falcon   Unintentional   Explosion
# 9419         21  Unknown          Phillipines  Meteorological     Typhoon
# 1972         30  Unknown              Glasgow   Unintentional       Crash
# 24446        21       AU      New South Wales  Climatological    Wildfire
# 12125        36       BD                Savar   Unintentional    Collapse
# 27873        13       IT             Sardinia    Hydrological      Floods
# 2055         30  Unknown              Glasgow   Unintentional       Crash
# 15053        12  Unknown          Phillipines     Geophysical  Earthquake
# 4667         12  Unknown          Los Angeles     Intentional   Shootings
# 8365         19  Unknown          Chelyabinsk          Others   Meteorite
# 24958        20       GT            Guatemala     Geophysical  Earthquake
# 5043         12  Unknown          Los Angeles     Intentional   Shootings
# 27606        13       IT             Sardinia    Hydrological      Floods
# 7602         19  Unknown          Chelyabinsk          Others   Meteorite
# 26296        19       AU           Queensland    Hydrological      Floods
# 21370        32       IT               Modena     Geophysical  Earthquake
# 27279        13       IT             Sardinia    Hydrological      Floods
# 16408        60  Unknown               Boston     Intentional    Bombings
# 9733         21  Unknown          Phillipines  Meteorological     Typhoon
# 10574        21  Unknown             Colorado    Hydrological      Floods
#
#                                             country_pred  \
# 17799                                     Not applicable
# 9419                                                 PHP
# 1972     Based on the text you provided, the most app...
# 24446                                                AUS
# 12125                                    Bangladesh (BD)
# 27873                                                 IT
# 2055                                                  US
# 15053    Based on the text you provided, the most app...
# 4667                                                 USA
# 8365                                      Not applicable
# 24958                                     Guatemala (GT)
# 5043                                                 USA
# 27606              The ISO country code for Italy is IT.
# 7602     Based on the text provided, the most appropr...
# 26296                                                 AU
# 21370                                     Not applicable
# 27279                                                 IT
# 16408                                     Not applicable
# 9733       The ISO country code for Philippines is "PH".
# 10574                                                USA
#
#                                     Informativeness_pred
# 17799                           Related and informative.
# 9419     Based on the information provided, I would c...
# 1972     Based on the information provided in the twe...
# 24446                            Related and informative
# 12125    Based on the provided URL, I would classify ...
# 27873                           Related and informative.
# 2055     Based on the information provided, I would c...
# 15053                            Related and informative
# 4667                             Related and informative
# 8365                             Related and informative
# 24958    Based on the information provided, I would c...
# 5043                             Related and informative
# 27606    Based on the text you provided, I would clas...
# 7602     Based on the provided URL, I would classify ...
# 26296                            Related and informative
# 21370                            Related and informative
# 27279    Based on the provided text, I would classify...
# 16408    Based on the tweet you provided, I would cla...
# 9733     Based on the information provided, I would c...
# 10574                           Related and informative.

# %%
answer_1 = testing_df.iloc[1, 15]
print(answer_1)


answer_1 = testing_df.iloc[1, 4]
print(answer_1)
# Out:
#   Based on the information provided, I would classify the text as "Related and informative". The text mentions a powerful typhoon pounding the southern Philippines, which is a clear indication of a crisis situation. The mention of Typhoon Pablo in the tweet also suggests that the text is related to a previous crisis event. Therefore, I would label the text as "Related and informative".
# Related and informative

# %% [markdown]
# ## Performance Evaluation
